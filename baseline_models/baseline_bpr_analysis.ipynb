# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Loss = 4562117.93, HR = 0.0675, NDCG = 0.0295,
Loss = 2208208.91, HR = 0.3906, NDCG = 0.2045,
Loss = 1237804.73, HR = 0.4864, NDCG = 0.2701,
Loss = 1028367.94, HR = 0.5346, NDCG = 0.2987,
Loss = 907053.87 , HR = 0.5687, NDCG = 0.3215,
Loss = 840797.33 , HR = 0.5887, NDCG = 0.3357,
Loss = 801354.48 , HR = 0.6108, NDCG = 0.3478,
Loss = 774289.96 , HR = 0.6219, NDCG = 0.3560,
Loss = 756206.46 , HR = 0.6351, NDCG = 0.3614,
Loss = 741552.22 , HR = 0.6450, NDCG = 0.3686,
Loss = 730765.32 , HR = 0.6497, NDCG = 0.3736,
Loss = 724218.92 , HR = 0.6522, NDCG = 0.3748,
Loss = 719013.92 , HR = 0.6591, NDCG = 0.3775,
Loss = 714828.14 , HR = 0.6598, NDCG = 0.3789,
Loss = 711240.84 , HR = 0.6647, NDCG = 0.3831,
Loss = 708806.29 , HR = 0.6649, NDCG = 0.3850,
Loss = 706298.96 , HR = 0.6671, NDCG = 0.3854,
Loss = 706574.87 , HR = 0.6700, NDCG = 0.3845,
Loss = 703540.12 , HR = 0.6689, NDCG = 0.3876,
Loss = 703465.40 , HR = 0.6672, NDCG = 0.3857,
Loss = 703554.40 , HR = 0.6719, NDCG = 0.3887,
Loss = 702832.34 , HR = 0.6724, NDCG = 0.3893,
Loss = 701687.76 , HR = 0.6697, NDCG = 0.3873,
Loss = 700051.35 , HR = 0.6722, NDCG = 0.3904,
Loss = 699112.30 , HR = 0.6730, NDCG = 0.3898,

# %%
loss_bs512_lr001_dim8_l2_0 = [4562117.93,2208208.91,1237804.73,1028367.94,907053.87 ,840797.33 ,801354.48 ,774289.96 ,756206.46 ,741552.22 ,730765.32 ,724218.92 ,719013.92 ,714828.14 ,711240.84 ,708806.29 ,706298.96 ,706574.87 ,703540.12 ,703465.40 ,703554.40 ,702832.34 ,701687.76 ,700051.35 ,699112.30 ,]
hr_bs512_lr001_dim8_l2_0   = [0.0675,0.3906,0.4864,0.5346,0.5687,0.5887,0.6108,0.6219,0.6351,0.6450,0.6497,0.6522,0.6591,0.6598,0.6647,0.6649,0.6671,0.6700,0.6689,0.6672,0.6719,0.6724,0.6697,0.6722,0.6730,]
ndcg_bs512_lr001_dim8_l2_0 = [0.0295,0.2045,0.2701,0.2987,0.3215,0.3357,0.3478,0.3560,0.3614,0.3686,0.3736,0.3748,0.3775,0.3789,0.3831,0.3850,0.3854,0.3845,0.3876,0.3857,0.3887,0.3893,0.3873,0.3904,0.3898,]

loss_bs512_lr001_dim8_l2_1e_7 = [4493960.71, 2113870.02, 1205909.17, 1031522.13, 910964.30, 831698.30, 788886.05, 757939.37, 741027.21,728994.90, 719912.77, 713987.84, 709736.85, 705854.61, 704916.43, 701005.59, 701189.89, 701124.06, 699020.07, 698137.49, 698106.68, 697551.18, 696226.71, 697064.52, 695885.45,]
loss_bs512_lr005_dim32_l2_0 = [3586891.95,767445.69, 651790.27, 611097.49, 594045.23, 581249.94, 576450.45, 569558.48, 566741.03, 562808.47, 563328.49, 561721.35, 559634.13, 559037.61, 558373.55, 557934.66, 558449.77, 557024.50, 558298.57, 555611.89, 556969.46, 555764.15, 553788.06, 556079.04, 555735.97, ]
hr_bs512_lr005_dim32_l2_0   = [0.5127,0.6281,0.6530,0.6712,0.6669,0.6826,0.6853,0.6891,0.6856,0.6935,0.6932,0.6877,0.6884,0.6932,0.6896,0.6889,0.6927,0.6925,0.6939,0.6874,0.6904,0.6950,0.6873,0.6919,0.6899,]
ndcg_bs512_lr005_dim32_l2_0 = [0.2786,0.3596,0.3801,0.3893,0.3898,0.4030,0.4024,0.4046,0.4056,0.4095,0.4117,0.4097,0.4073,0.4073,0.4052,0.4064,0.4088,0.4080,0.4109,0.4077,0.4102,0.4085,0.4062,0.4114,0.4055,]

loss_bs512_lr005_dim64_l2_07 = [4986606.39,797769.40 ,632673.73 ,579763.52 ,555547.10 ,541215.60 ,530147.44 ,525912.33 ,522509.16 ,519620.36 ,516467.31 ,515938.67 ,512999.03 ,510346.12 ,512989.19 ,510101.18 ,508638.75 ,509346.72 ,510108.05 ,509381.20 ,507922.79 ,509003.90 ,509159.24 ,507524.99 ,510543.04 ,]
hr_bs512_lr005_dim64_l2_07   = [0.4811,0.6113,0.6421,0.6502,0.6599,0.6613,0.6667,0.6661,0.6705,0.6737,0.6755,0.6795,0.6783,0.6700,0.6781,0.6810,0.6826,0.6710,0.6795,0.6783,0.6851,0.6823,0.6846,0.6810,0.6820,]
ndcg_bs512_lr005_dim64_l2_07 = [0.2568, 0.3411, 0.3642, 0.3782, 0.3895, 0.3957, 0.3978, 0.3962, 0.3976, 0.4011, 0.4018, 0.4028, 0.4069, 0.4015, 0.4070, 0.4057, 0.4062, 0.4093, 0.4070, 0.4079, 0.4106, 0.4087, 0.4073, 0.4129, 0.4126]

loss_bs1024_lr005_dim64_l2_0 = [6956525.28,1081687.78,670925.93 ,569669.57 ,524668.04 ,497199.73 ,480131.86 ,465466.54 ,458565.10 ,452594.77 ,447404.38 ,442680.42 ,438038.23 ,436874.13 ,433966.91 ,431188.53 ,430563.15 ,429477.80 ,427691.53 ,425508.91 ,424743.08 ,425948.26 ,422464.00 ,423438.89 ,423675.69 ,]
hr_bs1024_lr005_dim64_l2_0   = [0.3674,0.5396,0.6071,0.6377,0.6472,0.6575,0.6591,0.6709,0.6728,0.6823,0.6813,0.6798,0.6796,0.6839,0.6839,0.6828,0.6889,0.6935,0.6856,0.6846,0.6911,0.6921,0.6950,0.6897,0.6853,]
ndcg_bs1024_lr005_dim64_l2_0 = [0.1882,0.2887,0.3394,0.3644,0.3776,0.3831,0.3898,0.3968,0.3958,0.4028,0.4026,0.4022,0.4055,0.4099,0.4098,0.4113,0.4123,0.4155,0.4141,0.4156,0.4159,0.4168,0.4182,0.4140,0.4107,]

# %%
epochs = np.arange(25)
plt.title("BPR_CF Tuning")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.plot(epochs, loss_bs512_lr001_dim8_l2_0    , label = "batch_size=512, lr=0.001, dim=8 , l2_reg=0")
plt.plot(epochs, loss_bs512_lr001_dim8_l2_1e_7 , label = "batch_size=512, lr=0.001, dim=8 , l2_reg=1e-07")
plt.plot(epochs, loss_bs512_lr001_dim16_l2_0   , label = "batch_size=512, lr=0.001, dim=16, l2_reg=0")
plt.plot(epochs, loss_bs512_lr001_dim16_l2_1e_7, label = "batch_size=512, lr=0.001, dim=16, l2_reg=1e-07")
plt.plot(epochs, loss_bs512_lr005_dim32_l2_0,    label = "batch_size=512, lr=0.005, dim=32, l2_reg=0")
plt.plot(epochs, loss_bs512_lr005_dim64_l2_07,   label = "batch_size=512, lr=0.005, dim=64, l2_reg=1e-07")
plt.plot(epochs, loss_bs1024_lr005_dim64_l2_0,   label = "batch_size=1024,lr=0.005, dim=64, l2_reg=0")
plt.legend(loc="best")

# %%
plt.title("BPR_CF Tuning")
plt.xlabel("epochs")
plt.ylabel("HR@10")
plt.plot(epochs, hr_bs512_lr001_dim8_l2_0    , label = "batch_size=512, lr=0.001, dim=8 , l2_reg=0")
plt.plot(epochs, hr_bs512_lr001_dim8_l2_1e_7 , label = "batch_size=512, lr=0.001, dim=8 , l2_reg=1e-07")
plt.plot(epochs, hr_bs512_lr001_dim16_l2_0   , label = "batch_size=512, lr=0.001, dim=16, l2_reg=0")
plt.plot(epochs, hr_bs512_lr001_dim16_l2_1e_7, label = "batch_size=512, lr=0.001, dim=16, l2_reg=1e-07")
plt.plot(epochs, hr_bs512_lr005_dim32_l2_0,    label = "batch_size=512, lr=0.005, dim=32, l2_reg=0")
plt.plot(epochs, hr_bs512_lr005_dim64_l2_07,   label = "batch_size=512, lr=0.005, dim=64, l2_reg=1e-07")
plt.plot(epochs, hr_bs1024_lr005_dim64_l2_0,   label = "batch_size=1024,lr=0.005, dim=64, l2_reg=0")
plt.legend(loc="best")

# %%
plt.title("BPR_CF Tuning")
plt.xlabel("epochs")
plt.ylabel("NDCG@10")
plt.plot(epochs, ndcg_bs512_lr001_dim8_l2_0    , label = "batch_size=512, lr=0.001, dim=8 , l2_reg=0")
plt.plot(epochs, ndcg_bs512_lr001_dim8_l2_1e_7 , label = "batch_size=512, lr=0.001, dim=8 , l2_reg=1e-07")
plt.plot(epochs, ndcg_bs512_lr001_dim16_l2_0   , label = "batch_size=512, lr=0.001, dim=16, l2_reg=0")
plt.plot(epochs, ndcg_bs512_lr001_dim16_l2_1e_7, label = "batch_size=512, lr=0.001, dim=16, l2_reg=1e-07")
plt.plot(epochs, ndcg_bs512_lr005_dim32_l2_0,    label = "batch_size=512, lr=0.005, dim=32, l2_reg=0")
plt.plot(epochs, ndcg_bs512_lr005_dim64_l2_07,   label = "batch_size=512, lr=0.005, dim=64, l2_reg=1e-07")
plt.plot(epochs, ndcg_bs1024_lr005_dim64_l2_0,   label = "batch_size=1024,lr=0.005, dim=64, l2_reg=0")
plt.legend(loc="best")
